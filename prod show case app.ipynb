# %%
import pandas as pd

stuDF = pd.read_csv('koramangala/stu.csv')
volDF = pd.read_csv('koramangala/vol.csv')

# %%
listOfActivities=['Drama','Dance','Computer','Science','Guitar','Singing','Public speaking','Art and Craft','Games']
activityAndSize=[]

for act in listOfActivities:
    activityAndSize.append({'act':act,'size':0})

# %%
activityAndSize=[{'act': 'Drama', 'size': 10},
 {'act': 'Dance', 'size': 40},
 {'act': 'Computer', 'size': 10},
 {'act': 'Science', 'size': 15},
 {'act': 'Guitar', 'size': 6},
 {'act': 'Singing', 'size': 6},
 {'act': 'Public speaking', 'size': 6},
 {'act': 'Art and Craft', 'size': 6},
 {'act': 'Games', 'size': 10}]

# %%
activityAndSize
# Out:
# [{'act': 'Drama', 'size': 10},
#  {'act': 'Dance', 'size': 40},
#  {'act': 'Computer', 'size': 10},
#  {'act': 'Science', 'size': 15},
#  {'act': 'Guitar', 'size': 6},
#  {'act': 'Singing', 'size': 6},
#  {'act': 'Public speaking', 'size': 6},
#  {'act': 'Art and Craft', 'size': 6},
#  {'act': 'Games', 'size': 10}]

# %%
masterKids=stuDF['name']

# %%
masterKids
# Out:
# 0                 Riya
# 1              Saritha
# 2            Huligavya
# 3            Vignesh v
# 4                Leena
# 5               Hanifa
# 6              Bhavani
# 7              Pruthvi
# 8                 Ajay
# 9             Abhishek
# 10           Annamalai
# 11        Anusuya devi
# 12             Karunya
# 13               Kavya
# 14            Sandhya8
# 15        Sashi Kumar
# 16             Nivedha
# 17         Stephen Raj
# 18            Prajwal
# 19       Baratha Gowda
# 20         Vikas kumar
# 21           Indumathi
# 22             Tasmia
# 23              Nuhira
# 24              Rameez
# 25            Sinchana
# 26             William
# 27             Vidya B
# 28             Niteesh
# 29            Shreya K
#             ...
# 51       Sharath Kumar
# 52               Divya
# 53               Robin
# 54        Nethravati Y
# 55    Deluwer Hossain
# 56       Mohammed Saif
# 57        Nethravati Y
# 58             Deepa R
# 59      Mohammed Zahid
# ...

# %%
volDF[volDF['name']=='Suhail']
# Out:
#          act    session    name class  rating
# 30     Dance  Session 2  Suhail     5     5.0
# 109  Singing  Session 1  Suhail     5     3.0
# 187    Dance  Session 3  Suhail     5     5.0

# %%
# volDF[volDF['act']=='Dance' and volDF['name']=='Bhavani']
# print(volDF.query('act=="Dance" and name=="Bhavani"')['rating'].get_value(0))
#     print('act=="'+stuDF.iloc[i]['p1']+'" and name=="'+stuDF.iloc[i]['name']+'"')
#     print(volDF.query('act=="'+stuDF.iloc[i]['p1']+'" and name=="'+stuDF.iloc[i]['name']+'"'))
#     stuDF.loci[i]['p1']=stuDF.loci[i]['p1']+'-'

manualSort=[]
softSort=[]
for i in range(0,len(stuDF)):
    print(stuDF.iloc[i]['name'])
    print(len(volDF.query('name=="'+stuDF.iloc[i]['name']+'"')['session']))
    if len(volDF.query('name=="'+stuDF.iloc[i]['name']+'"')['session'])<3:
        manualSort.append(stuDF.iloc[i])
    if len(volDF.query('name=="'+stuDF.iloc[i]['name']+'"')['session'])==3:
        softSort.append(stuDF.iloc[i])
    print("\n\n")
    

    
    
    
# print(manualSort)

manDF=pd.DataFrame(manualSort)
manDF
# Out:
# Riya
# 3
#
#
#
# Saritha
# 3
#
#
#
# Huligavya
# 3
#
#
#
# Vignesh v
# 1
#
#
#
# Leena
# 3
#
#
#
# Hanifa
# 2
#
#
#
# Bhavani
# 2
#
#
#
# Pruthvi
# 2
#
#
#
# Ajay
# 3
#
#
#
# Abhishek
# 2
#
#
#
# Annamalai
# 1
#
#
#
# Anusuya devi
# 2
#
#
#
# Karunya
# 2
#
#
#
# Kavya
# 3
#
#
#
# Sandhya8
# 0
#
#
#
# Sashi Kumar
# 3
#
#
#
# Nivedha
# 0
#
#
#
# Stephen Raj
# 3
#
#
#
# Prajwal
# 0
#
#
#
# Baratha Gowda
# 3
#
#
#
# Vikas kumar
# 2
#
#
#
# Indumathi
# 3
#
#
#
# Tasmia
# 0
#
#
#
# Nuhira
# 3
#
#
#
# Rameez
# 3
#
#
#
# Sinchana
# 2
#
#
#
# William
# 2
#
#
#
# Vidya B
# 2
#
#
#
# Niteesh
# 3
#
#
#
# Shreya K
# 2
#
#
#
# Ranjith Kumar
# 2
#
#
#
# Sandhya5
# 3
#
#
#
# Jamuna
# 3
#
#
#
# Gangamma
# 0
#
#
#
# Devi
# 3
#
#
#
# Tasmiya R
# 0
#
#
#
# Pooja5
# 3
#
#
#
# Nuhira
# 3
#
#
#
# Jayshree
# 2
#
#
#
# Gowri K
# 3
#
#
#
# Daneil
# 3
#
#
#
# Meesala Shruti
# 1
#
#
#
# Ismail
# 3
#
#
#
# Archana
# 3
#
#
#
# Husna R
# 2
#
#
#
# Veena B
# 2
#
#
#
# Eeshwari
# 3
#
#
#
# Mehak
# 2
#
#
#
# Ramya
# ...

# %%
sfDf=pd.DataFrame(softSort)
len(sfDf)
# Out:
# 32
